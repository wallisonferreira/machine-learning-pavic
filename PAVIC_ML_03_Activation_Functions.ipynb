# %% [markdown]
# <a href="https://colab.research.google.com/github/wallisonferreira/machine-learning-pavic/blob/main/PAVIC_ML_03_Activation_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as wg
from ipywidgets import interactive, fixed

# %matplotlib inline

# %%
def plot_interactive(w, b, func, ylim=fixed((0, 1)), show_der=False):
    plt.figure(0)

    x = np.linspace(-10, 10, num=1000)
    z = w*x + b
    y = func(z)

    plt.plot(x, y, color='blue')
    if show_der:
        der = func(z, derivative=True)
        y_der_z = der
        y_der_x = w*der
        plt.plot(x, y_der_z, color='red')
        plt.plot(x, y_der_x, color='green')
    plt.xlim(-10, 10)
    plt.ylim(ylim[0], ylim[1])
    plt.show()

# %% [markdown]
# # Linear

# %%
np.ones_like(1)
# Out:
# array(1)

# %%
def linear(x, derivative=False):
    return np.ones_like(x) if derivative else x

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(linear), ylim=fixed((-10, 10)))
interactive_plot
#vermelho eh a derivada 1 fixa, em verde a derivada considerando a soma ponderada do neuronio
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# # Sigmoid

# %%
def sigmoid(x, derivative=False):
    if derivative:
        y = sigmoid(x)
        return y * (1 - y)
    return 1.0 / (1.0 + np.exp(-x))

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(sigmoid))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# # Tanh

# %%
def tanh(x, derivative=False):
    if derivative:
        y = tanh(x)
        return 1 - (y**2)
    return ( np.exp(x) - np.exp(-x) ) / ( np.exp(x) + np.exp(-x) )

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(tanh), ylim=fixed((-2, 2)))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# # Rectified Linear Unit (ReLU)

# %%
def relu(x, derivative=False):
    if derivative:
        return np.where(x <= 0, 0, 1)
    return np.maximum(0, x)

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(relu), ylim=fixed((-1, 10)))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# A ativação vai ficar entre 0 e 1 (vermelho)

# %% [markdown]
# # Leaky ReLU

# %%
def leaky_relu(x, derivative=False):
    alpha = 0.1
    if derivative:
        return np.where( x <= 0, alpha, 1)
    return np.where( x <= 0, alpha * x, x)

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(leaky_relu), ylim=fixed((-1, 10)))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %% [markdown]
# # Exponential Linear Unit (eLU)

# %%
def elu(x, derivative=False):
    alpha = 1.0
    if derivative:
        y = elu(x)
        return np.where(x <= 0, y + alpha, 1)
    return np.where(x <= 0, alpha * (np.exp(x) - 1), x)

# %%
interactive_plot = interactive(plot_interactive, w=(-2.0, 2.0), b=(-3, 3, 0.5), func=fixed(elu), ylim=fixed((-2, 10)))
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='w', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…
